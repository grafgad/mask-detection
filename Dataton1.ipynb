# %%
from roboflow import Roboflow
from IPython.display import Image

with open('apikey.txt') as f:
    apikey = f.read()
    
rf = Roboflow(api_key=apikey)
project = rf.workspace().project("masks-detection-kwy1r")
model = project.version(3).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# infer on a local image
print(model.predict("mask.jpg", confidence=40, overlap=30).json())

# visualize your prediction
model.predict("mask.jpg", confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())

Image('prediction.jpg')
# Out:
# {'predictions': [{'x': 383, 'y': 369, 'width': 300, 'height': 438, 'confidence': 0.9125866889953613, 'class': 'with_mask', 'class_id': 11, 'image_path': 'mask.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '681', 'height': '893'}}
